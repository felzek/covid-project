# %%
import dask.dataframe as dd

# %%
df = dd.read_csv("/Users/bhanugarg/Downloads/time_series_covid19_confirmed_global_iso3_regions.csv")

# %%
df
# Out:
# Dask DataFrame Structure:
# ...

# %%
df.head
# Out:
# <bound method _Frame.head of Dask DataFrame Structure:
# ...

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat      Long  1/22/20  1/23/20  \
# 0     #adm1+name  #country+name  #geo+lat  #geo+lon      NaN      NaN
# 1            NaN    Afghanistan      33.0      65.0      0.0      0.0
# 2            NaN        Albania   41.1533   20.1683      0.0      0.0
# 3            NaN        Algeria   28.0339    1.6596      0.0      0.0
# 4            NaN        Andorra   42.5063    1.5218      0.0      0.0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/14/20  6/15/20  6/16/20  \
# 0      NaN      NaN      NaN      NaN  ...      NaN      NaN      NaN
# 1      0.0      0.0      0.0      0.0  ...  24766.0  25527.0  26310.0
# 2      0.0      0.0      0.0      0.0  ...   1521.0   1590.0   1672.0
# 3      0.0      0.0      0.0      0.0  ...  10919.0  11031.0  11147.0
# 4      0.0      0.0      0.0      0.0  ...    853.0    853.0    854.0
#
#    ISO 3166-1 Alpha 3-Codes        Region Code        Region Name  \
# ...
